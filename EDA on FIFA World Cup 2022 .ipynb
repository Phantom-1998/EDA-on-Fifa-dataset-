# %% [markdown]
# ## Importing Initial Libraries

# %% [markdown]
# importing numpy, pandas, seaborn and matplotlib for reading data and visualize the data

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Mounting the data i.e Linking drive

# %% [markdown]
# Mounting - This is the process of making files and directories on a storage device accessible to users via a computer's file system

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Reading file using pandas library

# %%
data = pd.read_csv('/content/drive/MyDrive/international_matches.csv')

# %%
data.head()
# Out:
#          date home_team     away_team home_team_continent away_team_continent  \
# 0  1993-08-08   Bolivia       Uruguay       South America       South America
# 1  1993-08-08    Brazil        Mexico       South America       North America
# 2  1993-08-08   Ecuador     Venezuela       South America       South America
# 3  1993-08-08    Guinea  Sierra Leone              Africa              Africa
# 4  1993-08-08  Paraguay     Argentina       South America       South America
#
#    home_team_fifa_rank  away_team_fifa_rank  home_team_total_fifa_points  \
# 0                   59                   22                            0
# 1                    8                   14                            0
# 2                   35                   94                            0
# 3                   65                   86                            0
# 4                   67                    5                            0
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23921 entries, 0 to 23920
# Data columns (total 25 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   date                           23921 non-null  object
#  1   home_team                      23921 non-null  object
#  2   away_team                      23921 non-null  object
#  3   home_team_continent            23921 non-null  object
#  4   away_team_continent            23921 non-null  object
#  5   home_team_fifa_rank            23921 non-null  int64
#  6   away_team_fifa_rank            23921 non-null  int64
#  7   home_team_total_fifa_points    23921 non-null  int64
#  8   away_team_total_fifa_points    23921 non-null  int64
#  9   home_team_score                23921 non-null  int64
#  10  away_team_score                23921 non-null  int64
#  11  tournament                     23921 non-null  object
# ...

# %% [markdown]
# 1) Std - Standard deviaton i.i sqrt of mean(x)
# 2) 25th percentile - it is konwn as the lower quartile.
# 3) 50th percentile - it is known as the median.
# 4) 75th percentile -  known as the upper quartile.

# %%
data.describe()
# Out:
#        home_team_fifa_rank  away_team_fifa_rank  home_team_total_fifa_points  \
# count         23921.000000         23921.000000                 23921.000000
# mean             77.854688            80.797375                   323.401488
# std              52.355225            53.232902                   500.825725
# min               1.000000             1.000000                     0.000000
# 25%              33.000000            36.000000                     0.000000
# 50%              71.000000            73.000000                     0.000000
# 75%             115.000000           119.000000                   547.000000
# max             211.000000           211.000000                  2164.000000
#
#        away_team_total_fifa_points  home_team_score  away_team_score  \
# count                 23921.000000     23921.000000     23921.000000
# mean                    315.453576         1.609214         1.068266
# ...

# %%
data.head(5)
# Out:
#          date home_team     away_team home_team_continent away_team_continent  \
# 0  1993-08-08   Bolivia       Uruguay       South America       South America
# 1  1993-08-08    Brazil        Mexico       South America       North America
# 2  1993-08-08   Ecuador     Venezuela       South America       South America
# 3  1993-08-08    Guinea  Sierra Leone              Africa              Africa
# 4  1993-08-08  Paraguay     Argentina       South America       South America
#
#    home_team_fifa_rank  away_team_fifa_rank  home_team_total_fifa_points  \
# 0                   59                   22                            0
# 1                    8                   14                            0
# 2                   35                   94                            0
# 3                   65                   86                            0
# 4                   67                    5                            0
#
# ...

# %% [markdown]
# ## Using this code we will the filter data from 2022

# %%
data = data[data['date'] > '2022-01-01']

# %%
data = data.reset_index()

# %%
data.columns
# Out:
# Index(['index', 'date', 'home_team', 'away_team', 'home_team_continent',
#        'away_team_continent', 'home_team_fifa_rank', 'away_team_fifa_rank',
#        'home_team_total_fifa_points', 'away_team_total_fifa_points',
#        'home_team_score', 'away_team_score', 'tournament', 'city', 'country',
#        'neutral_location', 'shoot_out', 'home_team_result',
#        'home_team_goalkeeper_score', 'away_team_goalkeeper_score',
#        'home_team_mean_defense_score', 'home_team_mean_offense_score',
#        'home_team_mean_midfield_score', 'away_team_mean_defense_score',
#        'away_team_mean_offense_score', 'away_team_mean_midfield_score'],
#       dtype='object')

# %%
last_date  = data.sort_values(['home_team', 'date'], ascending=[True, False])

# %% [markdown]
# Cumcount genearates a total count. For exp, by grouping by person name and then applying cumcount, we can take only the second activity for ach person. This simply counts the activity in the order they occurred.

# %%
data['last_date'] = last_date.groupby('home_team').cumcount()+1

# %% [markdown]
# ## Data after Using Filter

# %%
data.head()
# Out:
#    index        date   home_team     away_team home_team_continent  \
# 0  23350  2022-01-02       Gabon  Burkina Faso              Africa
# 1  23351  2022-01-02       Sudan      Zimbabwe              Africa
# 2  23352  2022-01-03      Rwanda        Guinea              Africa
# 3  23353  2022-01-04  Mauritania         Gabon              Africa
# 4  23354  2022-01-05     Algeria         Ghana              Africa
#
#   away_team_continent  home_team_fifa_rank  away_team_fifa_rank  \
# 0              Africa                   89                   60
# 1              Africa                  125                  121
# 2              Africa                  135                   81
# 3              Africa                  103                   89
# 4              Africa                   29                   52
#
#    home_team_total_fifa_points  away_team_total_fifa_points  ...  \
# 0                         1262                         1397  ...
# ...

# %% [markdown]
# unique() function Finds the unique elements of an array and returns them as a sorted array.

# %%
print(data["home_team"].unique())
# Out:
# ['Gabon' 'Sudan' 'Rwanda' 'Mauritania' 'Algeria' 'Cameroon' 'Ethiopia'
#  'Senegal' 'Guinea' 'Morocco' 'Comoros' 'Nigeria' 'Iceland'
#  'Equatorial Guinea' 'Tunisia' 'Cabo Verde' 'Malawi' 'Korea Republic'
#  'Guinea-Bissau' 'Colombia' 'Peru' "Côte d'Ivoire" 'Gambia' 'Burkina Faso'
#  'Moldova' 'Zimbabwe' 'Ghana' 'Egypt' 'Sierra Leone' 'Mali' 'Bolivia'
#  'Iraq' 'Bahrain' 'Indonesia' 'Uzbekistan' 'Jamaica' 'USA' 'Honduras'
#  'Costa Rica' 'Lebanon' 'IR Iran' 'United Arab Emirates' 'Japan'
#  'Australia' 'Saudi Arabia' 'Ecuador' 'Paraguay' 'Chile' 'Jordan'
#  'Suriname' 'Venezuela' 'Kuwait' 'Nepal' 'Nicaragua' 'Canada' 'Mexico'
#  'Panama' 'Syria' 'Vietnam' 'Oman' 'Uruguay' 'Argentina' 'Brazil'
#  'El Salvador' 'Cook Islands' 'Papua New Guinea' 'New Caledonia'
#  'Mauritius' 'New Zealand' 'Gibraltar' 'Laos' 'Malaysia' 'Mozambique'
#  'Tanzania' 'Chad' 'Djibouti' 'Seychelles' 'Somalia' 'China PR'
#  'Solomon Islands' 'Fiji' 'Italy' 'Portugal' 'Sweden' 'Wales' 'Armenia'
# ...

# %%
print(data["away_team"].unique())
# Out:
# ['Burkina Faso' 'Zimbabwe' 'Guinea' 'Gabon' 'Ghana' 'Cabo Verde' 'Malawi'
#  'Egypt' 'Guinea-Bissau' 'Sierra Leone' 'Uganda' "Côte d'Ivoire" 'Mali'
#  'Gambia' 'Ethiopia' 'Comoros' 'Iceland' 'Sudan' 'Honduras' 'Panama'
#  'Equatorial Guinea' 'Mauritania' 'Senegal' 'Morocco' 'Nigeria' 'Moldova'
#  'Jamaica' 'Algeria' 'Tunisia' 'Trinidad and Tobago' 'Timor-Leste'
#  'South Sudan' 'Mexico' 'El Salvador' 'Canada' 'Korea Republic' 'Iraq'
#  'Syria' 'China PR' 'Vietnam' 'Oman' 'Brazil' 'Uruguay' 'Argentina'
#  'New Zealand' 'Barbados' 'Peru' 'Bolivia' 'Libya' 'Mauritius' 'Belize'
#  'USA' 'Costa Rica' 'Congo DR' 'Guyana' 'United Arab Emirates'
#  'Saudi Arabia' 'Australia' 'Chile' 'Venezuela' 'Colombia' 'Ecuador'
#  'Paraguay' 'Solomon Islands' 'Fiji' 'Zambia' 'Seychelles' 'New Caledonia'
#  'India' 'Grenada' 'Mongolia' 'Philippines' 'Niger'
#  'Central African Republic' 'Lesotho' 'Eswatini' 'IR Iran' 'Japan'
#  'Tahiti' 'Papua New Guinea' 'North Macedonia' 'Turkey' 'Czech Republic'
# ...

# %%
teams_worldcup = ['Qatar', 'Ecuador', 'Senegal', 'Netherlands', 'England', 'Iran', 'USA',
                  'Wales', 'Argentina', 'Saudi Arabia', 'Mexico', 'Poland', 'France', 
                  'Australia', 'Denmark', 'Tunisia', 'Spain', 'Costa Rica', 'Germany', 
                  'Japan', 'Belgium', 'Canada', 'Morocco', 'Croatia', 'Brazil', 'Serbia', 
                  'Switzerland', 'Cameroon', 'Portugal', 'Ghana', 'Uruguay', 'South Korea']

# %% [markdown]
# ## Checking the data of home team with the teams in World Cup

# %%
data = data[data['home_team'].isin(teams_worldcup)]

# %% [markdown]
# ## Using nlargest Function (to have 20 samples)

# %% [markdown]
# nLargest () funstion it returns the largest value in the column

# %%
fifa_points = data.nlargest(20, 'home_team_total_fifa_points')

# %% [markdown]
# ## Plotting graphs to have a look into data points

# %%
plt.figure(figsize=(6,4),dpi=200)
sns.barplot(data=fifa_points,y='home_team',x='home_team_total_fifa_points')
plt.title("Fifa Points");

# %% [markdown]
# ## Finding Correlation between Data Points (By Pairplot)

# %%
sns.pairplot(
    data,
    x_vars=["home_team_fifa_rank", "home_team_total_fifa_points"],
    y_vars=["away_team_fifa_rank", "away_team_total_fifa_points"],
)

# %%
data
# Out:
#      index        date    home_team     away_team home_team_continent  \
# 6    23356  2022-01-09     Cameroon  Burkina Faso              Africa
# 8    23358  2022-01-10      Senegal      Zimbabwe              Africa
# 10   23360  2022-01-10      Morocco         Ghana              Africa
# 17   23367  2022-01-12      Tunisia          Mali              Africa
# 19   23369  2022-01-13     Cameroon      Ethiopia              Africa
# ..     ...         ...          ...           ...                 ...
# 556  23906  2022-06-14      England       Hungary              Europe
# 557  23907  2022-06-14      Germany         Italy              Europe
# 558  23908  2022-06-14  Netherlands         Wales              Europe
# 559  23909  2022-06-14       Poland       Belgium              Europe
# 569  23919  2022-06-14        Japan       Tunisia                Asia
#
#     away_team_continent  home_team_fifa_rank  away_team_fifa_rank  \
# ...

# %%
plt.figure(figsize=(20,6))
plt.title("Home Teams Fifa Points")
sns.barplot(data=fifa_points, x = 'home_team', y ='home_team_total_fifa_points');

# %%
plt.figure(figsize=(30,6))
plt.title("Away  Teams Fifa Points")
sns.barplot(data=fifa_points, x = 'away_team', y ='away_team_total_fifa_points');

# %%
Home_team_fifa_points = data.head(10)

# %%
Home_team_fifa_points
# Out:
#     index        date home_team     away_team home_team_continent  \
# 6   23356  2022-01-09  Cameroon  Burkina Faso              Africa
# 8   23358  2022-01-10   Senegal      Zimbabwe              Africa
# 10  23360  2022-01-10   Morocco         Ghana              Africa
# 17  23367  2022-01-12   Tunisia          Mali              Africa
# 19  23369  2022-01-13  Cameroon      Ethiopia              Africa
# 21  23371  2022-01-14   Senegal        Guinea              Africa
# 23  23373  2022-01-14   Morocco       Comoros              Africa
# 33  23383  2022-01-16   Tunisia    Mauritania              Africa
# 35  23385  2022-01-17  Cameroon    Cabo Verde              Africa
# 40  23390  2022-01-18     Ghana       Comoros              Africa
#
#    away_team_continent  home_team_fifa_rank  away_team_fifa_rank  \
# 6               Africa                   50                   60
# 8               Africa                   20                  121
# ...

# %%
## new data frame for home team

hometeam = data[['date','home_team_score','away_team_score']]

hometeam
# Out:
#            date  home_team_score  away_team_score
# 6    2022-01-09                2                1
# 8    2022-01-10                1                0
# 10   2022-01-10                1                0
# 17   2022-01-12                0                1
# 19   2022-01-13                4                1
# ..          ...              ...              ...
# 556  2022-06-14                0                4
# 557  2022-06-14                5                2
# 558  2022-06-14                3                2
# 559  2022-06-14                0                1
# 569  2022-06-14                0                3
#
# [126 rows x 3 columns]

# %% [markdown]
# ## how many games do home team won and loss.

# %%
hometeam['home_team_score']>hometeam['away_team_score']
home_wins = hometeam.loc[hometeam['home_team_score']>hometeam['away_team_score']]
home_wins
# Out:
#            date  home_team_score  away_team_score
# 6    2022-01-09                2                1
# 8    2022-01-10                1                0
# 10   2022-01-10                1                0
# 19   2022-01-13                4                1
# 23   2022-01-14                2                0
# ..          ...              ...              ...
# 529  2022-06-13                2                0
# 534  2022-06-13                2                0
# 540  2022-06-14                1                0
# 557  2022-06-14                5                2
# 558  2022-06-14                3                2
#
# [80 rows x 3 columns]

# %%
hometeam['home_team_score']<hometeam['away_team_score']
home_loss = hometeam.loc[hometeam['home_team_score']<hometeam['away_team_score']]
home_loss
# Out:
#            date  home_team_score  away_team_score
# 17   2022-01-12                0                1
# 40   2022-01-18                2                3
# 142  2022-03-24                0                2
# 166  2022-03-25                0                1
# 326  2022-06-02                0                1
# 337  2022-06-02                0                3
# 346  2022-06-03                0                3
# 347  2022-06-03                1                2
# 348  2022-06-03                1                4
# 394  2022-06-05                0                1
# 410  2022-06-06                0                1
# 443  2022-06-08                1                2
# 461  2022-06-09                0                1
# 471  2022-06-09                0                1
# 477  2022-06-10                0                1
# 535  2022-06-13                0                1
# 556  2022-06-14                0                4
# 559  2022-06-14                0                1
# ...

# %%
# Append the data (merge data) finding advantage for home team Win and Loss

home_ad = home_wins[['date', 'home_team_score', 'away_team_score']].rename(columns = {'home_team_score': 'Home_team_win', 'away_team_score' :'Home_team_loss'})
away_ad = home_loss[['date', 'home_team_score', 'away_team_score']].rename(columns = {'home_team_score': 'Home_team_win', 'away_team_score' :'Home_team_loss'})
home_advantage = home_ad.append(away_ad)

home_advantage
# Out:
#            date  Home_team_win  Home_team_loss
# 6    2022-01-09              2               1
# 8    2022-01-10              1               0
# 10   2022-01-10              1               0
# 19   2022-01-13              4               1
# 23   2022-01-14              2               0
# ..          ...            ...             ...
# 477  2022-06-10              0               1
# 535  2022-06-13              0               1
# 556  2022-06-14              0               4
# 559  2022-06-14              0               1
# 569  2022-06-14              0               3
#
# [99 rows x 3 columns]

# %% [markdown]
# ## Taking a mean to evaluate the ratio of win and loss

# %%
home_advantage.mean()
# Out:
# <ipython-input-30-ed8f96f0f920>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   home_advantage.mean()
# Home_team_win     2.171717
# Home_team_loss    0.666667
# dtype: float64

# %%
home_advantage.mean().plot(kind='pie', title='Home Advantage', labels =['Home team wins','Home team loss'], figsize=(6,6))
plt.legend();
# Out:
# <ipython-input-31-69d6a44fd707>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   home_advantage.mean().plot(kind='pie', title='Home Advantage', labels =['Home team wins','Home team loss'], figsize=(6,6))

# %% [markdown]
# ## Teams having strong defense

# %%
home_defense = data[['date','home_team','home_team_mean_defense_score']].rename(columns= {'home_team':'team','home_team_mean_defense_score':'defense_score'})
home_defense

away_defense = data[['date','away_team','away_team_mean_offense_score']].rename(columns= {'away_team':'team','away_team_mean_offense_score':'defense_score'})
away_defense

defense = home_defense.append(away_defense)

defense.dropna(subset=['defense_score'],inplace=True)
defense
# Out:
#            date      team  defense_score
# 6    2022-01-09  Cameroon           76.8
# 8    2022-01-10   Senegal           79.0
# 10   2022-01-10   Morocco           81.2
# 17   2022-01-12   Tunisia           70.8
# 19   2022-01-13  Cameroon           76.8
# ..          ...       ...            ...
# 556  2022-06-14   Hungary           72.7
# 557  2022-06-14     Italy           85.3
# 558  2022-06-14     Wales           73.0
# 559  2022-06-14   Belgium           85.7
# 569  2022-06-14   Tunisia           72.3
#
# [231 rows x 3 columns]

# %%
defense_top = defense.sort_values(by=['team','date'],ascending = [True,False])
defense_top
# Out:
#            date       team  defense_score
# 203  2022-03-26    Albania           70.0
# 166  2022-03-25    Algeria           81.0
# 391  2022-06-05  Argentina           82.2
# 236  2022-03-29  Argentina           89.0
# 171  2022-03-25  Argentina           82.2
# ..          ...        ...            ...
# 373  2022-06-05      Wales           75.0
# 308  2022-06-01      Wales           73.0
# 274  2022-03-29      Wales           75.0
# 153  2022-03-24      Wales           75.0
# 8    2022-01-10   Zimbabwe           72.3
#
# [231 rows x 3 columns]

# %%
defense_top_10 = defense_top.drop_duplicates(subset=["team"], keep='last').nlargest(10, 'defense_score')
defense_top_10
# Out:
#            date         team  defense_score
# 203  2022-03-26        Spain           86.5
# 72   2022-01-27       Brazil           86.3
# 501  2022-06-11        Italy           85.3
# 199  2022-03-26  Netherlands           85.2
# 151  2022-03-24     Portugal           85.2
# 193  2022-03-26      England           85.0
# 177  2022-03-25       France           84.2
# 195  2022-03-26      Germany           84.0
# 241  2022-03-29       Sweden           82.3
# 104  2022-02-01    Argentina           82.2

# %%
plt.figure(figsize=(14,6))
plt.title("Top 10 strongest defense")

sns.barplot(data=defense_top_10, x='team',y='defense_score');

# %% [markdown]
# ## Teams with Strong Midfield

# %%
home_midfield = data[['date','home_team','home_team_mean_midfield_score']].rename(columns ={'home_team':'team','home_team_mean_midfield_score':'midfield_score'})
home_midfield

away_midfield = data[['date','away_team','away_team_mean_midfield_score']].rename(columns ={'away_team':'team','away_team_mean_midfield_score':'midfield_score'})
away_midfield

midfield = home_midfield.append(away_midfield)

# %%
midfield.dropna(subset=['midfield_score'],inplace=True)
midfield
# Out:
#            date      team  midfield_score
# 6    2022-01-09  Cameroon            75.0
# 8    2022-01-10   Senegal            79.0
# 10   2022-01-10   Morocco            76.2
# 17   2022-01-12   Tunisia            74.0
# 19   2022-01-13  Cameroon            75.0
# ..          ...       ...             ...
# 556  2022-06-14   Hungary            73.0
# 557  2022-06-14     Italy            84.5
# 558  2022-06-14     Wales            78.5
# 559  2022-06-14   Belgium            85.5
# 569  2022-06-14   Tunisia            74.0
#
# [231 rows x 3 columns]

# %%
midfield_top = midfield.sort_values(by=['team','date'],ascending = [True,False])
midfield_top
# Out:
#            date       team  midfield_score
# 203  2022-03-26    Albania            73.0
# 166  2022-03-25    Algeria            78.0
# 391  2022-06-05  Argentina            84.0
# 236  2022-03-29  Argentina            84.0
# 171  2022-03-25  Argentina            84.0
# ..          ...        ...             ...
# 443  2022-06-08      Wales            78.5
# 373  2022-06-05      Wales            78.5
# 308  2022-06-01      Wales            78.5
# 274  2022-03-29      Wales            78.5
# 153  2022-03-24      Wales            78.5
#
# [231 rows x 3 columns]

# %%
midfield_top_10 = midfield_top.drop_duplicates(subset=["team"], keep='last').nlargest(10, 'midfield_score')
midfield_top_10
# Out:
#            date       team  midfield_score
# 195  2022-03-26    Germany            87.8
# 177  2022-03-25     France            86.8
# 203  2022-03-26      Spain            86.0
# 249  2022-03-29    Belgium            85.5
# 72   2022-01-27     Brazil            85.5
# 501  2022-06-11      Italy            84.5
# 151  2022-03-24   Portugal            84.5
# 192  2022-03-26    Croatia            84.2
# 104  2022-02-01  Argentina            84.0
# 193  2022-03-26    England            84.0

# %%
plt.figure(figsize=(14,6))
plt.title("Top 10 strongest midfield")
sns.barplot(data=midfield_top_10, x='team',y='midfield_score');

# %% [markdown]
# ## Teams with Strong Attacking

# %% [markdown]
# Creating new data frame and merging it to one data frame.

# %%
home_attack = data[['date','home_team','home_team_mean_offense_score']].rename(columns ={'home_team':'team','home_team_mean_offense_score':'offense_score'})
home_attack

away_attack = data[['date','away_team','away_team_mean_offense_score']].rename(columns ={'away_team':'team','away_team_mean_offense_score':'offense_score'})
away_attack

attack = home_attack.append(away_attack)

# %%
#drop nun values in the offense score column
attack.dropna(subset=['offense_score'],inplace=True)
attack
# Out:
#            date      team  offense_score
# 6    2022-01-09  Cameroon           77.7
# 8    2022-01-10   Senegal           80.7
# 10   2022-01-10   Morocco           81.7
# 17   2022-01-12   Tunisia           72.3
# 19   2022-01-13  Cameroon           77.7
# ..          ...       ...            ...
# 556  2022-06-14   Hungary           72.7
# 557  2022-06-14     Italy           85.3
# 558  2022-06-14     Wales           73.0
# 559  2022-06-14   Belgium           85.7
# 569  2022-06-14   Tunisia           72.3
#
# [231 rows x 3 columns]

# %%
attack_top = attack.sort_values(by=['team','date'],ascending = [True,False])
attack_top
# Out:
#            date       team  offense_score
# 203  2022-03-26    Albania           70.0
# 166  2022-03-25    Algeria           81.0
# 391  2022-06-05  Argentina           89.0
# 236  2022-03-29  Argentina           89.0
# 171  2022-03-25  Argentina           89.0
# ..          ...        ...            ...
# 373  2022-06-05      Wales           73.0
# 308  2022-06-01      Wales           73.0
# 274  2022-03-29      Wales           73.0
# 153  2022-03-24      Wales           73.0
# 8    2022-01-10   Zimbabwe           72.3
#
# [231 rows x 3 columns]

# %%
attack_top_10 = attack_top.drop_duplicates(subset=["team"], keep='last').nlargest(10, 'offense_score')
attack_top_10
# Out:
#            date       team  offense_score
# 104  2022-02-01  Argentina           89.0
# 177  2022-03-25     France           88.3
# 193  2022-03-26    England           88.0
# 72   2022-01-27     Brazil           86.3
# 151  2022-03-24   Portugal           86.0
# 249  2022-03-29    Belgium           85.7
# 501  2022-06-11      Italy           85.3
# 203  2022-03-26      Spain           85.0
# 241  2022-03-29     Poland           84.7
# 103  2022-02-01    Uruguay           84.3

# %%
plt.figure(figsize=(14,6))
plt.title("Top 10 strongest attack")
sns.barplot(data=attack_top_10, x='team',y='offense_score');

# %% [markdown]
# ## Teams with Most Wins.

# %%
home_team = data[['date','home_team','home_team_score','away_team_score']]

home_team.head(10)
# Out:
#           date home_team  home_team_score  away_team_score
# 6   2022-01-09  Cameroon                2                1
# 8   2022-01-10   Senegal                1                0
# 10  2022-01-10   Morocco                1                0
# 17  2022-01-12   Tunisia                0                1
# 19  2022-01-13  Cameroon                4                1
# 21  2022-01-14   Senegal                0                0
# 23  2022-01-14   Morocco                2                0
# 33  2022-01-16   Tunisia                4                0
# 35  2022-01-17  Cameroon                1                1
# 40  2022-01-18     Ghana                2                3

# %%
home_team.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 126 entries, 6 to 569
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   date             126 non-null    object
#  1   home_team        126 non-null    object
#  2   home_team_score  126 non-null    int64
#  3   away_team_score  126 non-null    int64
# dtypes: int64(2), object(2)
# memory usage: 4.9+ KB

# %%
home_team['home_team_score']>home_team['away_team_score']
homewins = home_team.loc[hometeam['home_team_score']>home_team['away_team_score']]
homewins
# Out:
#            date    home_team  home_team_score  away_team_score
# 6    2022-01-09     Cameroon                2                1
# 8    2022-01-10      Senegal                1                0
# 10   2022-01-10      Morocco                1                0
# 19   2022-01-13     Cameroon                4                1
# 23   2022-01-14      Morocco                2                0
# ..          ...          ...              ...              ...
# 529  2022-06-13      Morocco                2                0
# 534  2022-06-13      Denmark                2                0
# 540  2022-06-14   Costa Rica                1                0
# 557  2022-06-14      Germany                5                2
# 558  2022-06-14  Netherlands                3                2
#
# [80 rows x 4 columns]

# %% [markdown]
# ## Home team Wins

# %%
plt.figure(figsize=(20,6))
plt.title("Home Wins")
sns.barplot(data=homewins, x='home_team',y='home_team_score');

# %%
home_team['home_team_score']<home_team['away_team_score']
homeloss = home_team.loc[home_team['home_team_score']<home_team['away_team_score']]
homeloss
# Out:
#            date     home_team  home_team_score  away_team_score
# 17   2022-01-12       Tunisia                0                1
# 40   2022-01-18         Ghana                2                3
# 142  2022-03-24     Australia                0                2
# 166  2022-03-25      Cameroon                0                1
# 326  2022-06-02        Serbia                0                1
# 337  2022-06-02        Mexico                0                3
# 346  2022-06-03       Croatia                0                3
# 347  2022-06-03        France                1                2
# 348  2022-06-03       Belgium                1                4
# 394  2022-06-05  Saudi Arabia                0                1
# 410  2022-06-06         Japan                0                1
# 443  2022-06-08         Wales                1                2
# 461  2022-06-09   Switzerland                0                1
# 471  2022-06-09  Saudi Arabia                0                1
# ...

# %% [markdown]
# ## Home Team Losses

# %%
plt.figure(figsize=(14,6))
plt.title("Home losses")
sns.barplot(data=homeloss, x='home_team',y='away_team_score');

# %% [markdown]
# ## Team With Top streaks

# %% [markdown]
# Creating new data frame and merging it to one data frame.

# %%
hometeam_wins = homewins[['date', 'home_team','home_team_score', 'away_team_score']].rename(columns = {'home_team' : 'team','home_team_score': 'Home_team_win', 'away_team_score' :'away_team_win'})
awayteam_wins = homeloss[['date', 'home_team','home_team_score', 'away_team_score']].rename(columns = {'home_team': 'team','home_team_score': 'Home_team_win', 'away_team_score' :'away_team_win'})
Team_streak = hometeam_wins.append(awayteam_wins)

Team_streak
# Out:
#            date      team  Home_team_win  away_team_win
# 6    2022-01-09  Cameroon              2              1
# 8    2022-01-10   Senegal              1              0
# 10   2022-01-10   Morocco              1              0
# 19   2022-01-13  Cameroon              4              1
# 23   2022-01-14   Morocco              2              0
# ..          ...       ...            ...            ...
# 477  2022-06-10   Denmark              0              1
# 535  2022-06-13    France              0              1
# 556  2022-06-14   England              0              4
# 559  2022-06-14    Poland              0              1
# 569  2022-06-14     Japan              0              3
#
# [99 rows x 4 columns]

# %%
top_streak = Team_streak.sort_values(by=['team','date'],ascending = [False,True])
top_streak
# Out:
#            date       team  Home_team_win  away_team_win
# 153  2022-03-24      Wales              2              1
# 373  2022-06-05      Wales              1              0
# 443  2022-06-08      Wales              1              2
# 103  2022-02-01    Uruguay              4              1
# 149  2022-03-24    Uruguay              1              0
# ..          ...        ...            ...            ...
# 142  2022-03-24  Australia              0              2
# 309  2022-06-01  Australia              2              1
# 104  2022-02-01  Argentina              1              0
# 171  2022-03-25  Argentina              3              0
# 391  2022-06-05  Argentina              5              0
#
# [99 rows x 4 columns]

# %%
top_streak['team'].value_counts().nlargest(1)
# Out:
# Japan    6
# Name: team, dtype: int64
